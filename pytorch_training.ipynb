# %% [markdown]
# <a href="https://colab.research.google.com/github/ber-m-uda/pytorch-from-zero/blob/main/pytorch_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
my_list=[1,2,3,4,5,6]
a = np.array(my_list)
print("type:", type(a))
print(a)

# %%
# !git init
